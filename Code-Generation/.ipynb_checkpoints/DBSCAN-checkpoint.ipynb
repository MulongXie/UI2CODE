# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def read_compos(file='compo.json'):
    compos = json.load(open(file))['compos']
    df = pd.DataFrame(columns=['id', 'column_min', 'column_max', 'row_min', 'row_max', 'center', 'height', 'width', 'area', 'class'])
    for i, compo in enumerate(compos):
        compo['area'] = compo['height'] * compo['width']
        compo['center'] = ((compo['column_min'] + compo['column_max'])/2, (compo['row_min'] + compo['row_max'])/2)
        df.loc[i] = compo
    df = df[df['class'] != 'TextView']
    return df

# %%
def draw(org, compos, opt='class'):
    img_h, img_w = compos.iloc[0].height, compos.iloc[0].width
    img = cv2.resize(org, (img_w, img_h))
    board = img.copy()
    for i in range(len(compos)):
        compo = compos.iloc[i]
        board = cv2.rectangle(board, (compo.column_min, compo.row_min), (compo.column_max, compo.row_max), (255,0,0))
        board = cv2.putText(board, str(compo[opt]), (compo.column_min+5, compo.row_min+20), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,0,255), 1)
    
    cv2.imshow('board', board)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
def inspect_data(compos):
    import matplotlib.pyplot as plt
    plt.xlim(xmax=10000)
    plt.scatter(list(compos['area']), list(compos['id']))

# %%
def dbscan_clustering_by_area(org, compos):
    x = np.reshape(list(compos['area']), (-1, 1))
    from sklearn.cluster import DBSCAN
    clustering = DBSCAN(eps=200, min_samples=1).fit(x)
    clustering.labels_
    compos['cluster'] = clustering.labels_
    draw(org, compos, 'cluster')
    return max(compos['cluster'])

# %%
compos = read_compos()
org = cv2.imread('9.png')
# draw(org, compos)

# %%
cluster_num = dbscan_clustering_by_area(org, compos)
# Out:
# 10

# %%
compos.groupby('cluster').groups
# Out:
# {0: Int64Index([0], dtype='int64'),
#  1: Int64Index([1], dtype='int64'),
#  2: Int64Index([3], dtype='int64'),
#  3: Int64Index([4, 5, 6, 16, 26, 28, 29, 30, 31, 32, 33, 34, 83], dtype='int64'),
#  4: Int64Index([14], dtype='int64'),
#  5: Int64Index([15], dtype='int64'),
#  6: Int64Index([19, 20, 21, 22, 23], dtype='int64'),
#  7: Int64Index([40, 49, 57, 66, 71, 76, 80], dtype='int64'),
#  8: Int64Index([42, 47, 52], dtype='int64'),
#  9: Int64Index([84], dtype='int64'),
#  10: Int64Index([85], dtype='int64')}

# %%
compos
# Out:
#     id column_min column_max row_min row_max          center height width  \
# 0    0          0        635       0     800  (317.5, 400.0)    800   635
# 1    0          0        633       0      10    (316.5, 5.0)     10   633
# 3    2        133        434      20      42   (283.5, 31.0)     22   301
# 4    3        510        548      25      38   (529.0, 31.5)     13    38
# 5    4        567        597      27      37   (582.0, 32.0)     10    30
# 6    5         24         52      53      63    (38.0, 58.0)     10    28
# 14  13        460        611      85     172  (535.5, 128.5)     87   151
# 15  14         23        433      86     221  (228.0, 153.5)    135   410
# 16  15        462        475     175     189  (468.5, 182.0)     14    13
# 19  18         23        102     225     262   (62.5, 243.5)     37    79
# 20  19        106        185     225     262  (145.5, 243.5)     37    79
# 21  20        189        267     225     262  (228.0, 243.5)     37    78
# 22  21        271        350     225     262  (310.5, 243.5)     37    79
# 23  22        354        433     225     262  (393.5, 243.5)     37    79
# 26  25        546        554     224     229  (550.0, 226.5)      5     8
# 28  27        499        519     235     259  (509.0, 247.0)     24    20
# 29  28        540        559     235     251  (549.5, 243.0)     16    19
# 30  29        461        479     236     251  (470.0, 243.5)     15    18
# 31  30        581        599     236     251  (590.0, 243.5)     15    18
# 32  31        460        478     254     259  (469.0, 256.5)      5    18
# 33  32        539        552     254     259  (545.5, 256.5)      5    13
# 34  33        580        595     254     259  (587.5, 256.5)      5    15
# 40  39         23        126     290     348   (74.5, 319.0)     58   103
# 42  41        460        493     300     333  (476.5, 316.5)     33    33
# 47  46        460        493     340     373  (476.5, 356.5)     33    33
# 49  48         23        126     359     417   (74.5, 388.0)     58   103
# 52  51        460        493     379     412  (476.5, 395.5)     33    33
# 57  56         23        126     427     485   (74.5, 456.0)     58   103
# 66  65         23        126     495     554   (74.5, 524.5)     59   103
# 71  70         23        126     564     622   (74.5, 593.0)     58   103
# 76  75         23        126     632     690   (74.5, 661.0)     58   103
# 80  79         23        126     701     759   (74.5, 730.0)     58   103
# 83  82        224        232     770     778  (228.0, 774.0)      8     8
# 84  83        462        581     104     171  (521.5, 137.5)     67   119
# 85  84        269        432      86     219  (350.5, 152.5)    133   163
#
#       area       class  cluster
# 0   508000  Background        0
# 1     6330       Compo        1
# 3     6622       Compo        2
# 4      494       Compo        3
# 5      300       Compo        3
# 6      280       Compo        3
# 14   13137       Compo        4
# 15   55350       Compo        5
# 16     182       Compo        3
# 19    2923       Compo        6
# 20    2923       Compo        6
# 21    2886       Compo        6
# 22    2923       Compo        6
# 23    2923       Compo        6
# 26      40       Compo        3
# 28     480       Compo        3
# 29     304       Compo        3
# 30     270       Compo        3
# 31     270       Compo        3
# 32      90       Compo        3
# 33      65       Compo        3
# 34      75       Compo        3
# 40    5974       Compo        7
# 42    1089       Compo        8
# 47    1089       Compo        8
# 49    5974       Compo        7
# 52    1089       Compo        8
# 57    5974       Compo        7
# 66    6077       Compo        7
# 71    5974       Compo        7
# 76    5974       Compo        7
# 80    5974       Compo        7
# 83      64       Compo        3
# 84    7973       Block        9
# 85   21679       Block       10
