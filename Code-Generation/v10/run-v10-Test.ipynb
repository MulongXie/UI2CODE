# %%
import numpy as np
import pandas as pd

from obj.Compos_DF import ComposDF
from obj.Compo_HTML import *
from obj.List import *
from obj.Block import *
from obj.Group import *
from obj.React import *
from obj.Page import *
import lib.draw as draw

# %%
name = 'data/input/1'
compos = ComposDF(json_file=name + '.json', img_file=name + '.png')
img = compos.img.copy()
img_shape = compos.img_shape
img_re = cv2.resize(img, img_shape)

# %%
compos.compos_dataframe
# Out:
#                                                 clip column_min row_min  \
# 0        ../data/outputs/uied/base64_0/clips/bkg.png          0       0
# 1    ../data/outputs/uied/base64_0/clips/Compo/1.jpg          0       0
# 2    ../data/outputs/uied/base64_0/clips/Compo/2.jpg        406      40
# 3    ../data/outputs/uied/base64_0/clips/Compo/3.jpg         12      47
# 4    ../data/outputs/uied/base64_0/clips/Compo/4.jpg        205      47
# 5    ../data/outputs/uied/base64_0/clips/Compo/5.jpg          0      87
# 6    ../data/outputs/uied/base64_0/clips/Compo/6.jpg         19     143
# 7    ../data/outputs/uied/base64_0/clips/Compo/7.jpg         21     183
# 8    ../data/outputs/uied/base64_0/clips/Compo/8.jpg         12     213
# 9    ../data/outputs/uied/base64_0/clips/Compo/9.jpg         12     274
# 10  ../data/outputs/uied/base64_0/clips/Compo/10.jpg        319     273
# 11  ../data/outputs/uied/base64_0/clips/Compo/11.jpg         12     307
# 12  ../data/outputs/uied/base64_0/clips/Compo/12.jpg         46     313
# 13  ../data/outputs/uied/base64_0/clips/Compo/13.jpg         12     365
# 14  ../data/outputs/uied/base64_0/clips/Compo/14.jpg        152     365
# 15  ../data/outputs/uied/base64_0/clips/Compo/15.jpg         12     406
# 16  ../data/outputs/uied/base64_0/clips/Compo/16.jpg        339     466
# 17  ../data/outputs/uied/base64_0/clips/Compo/17.jpg         86     760
# 18  ../data/outputs/uied/base64_0/clips/Compo/18.jpg        339     760
# 19  ../data/outputs/uied/base64_0/clips/Compo/19.jpg        212     760
#
#    height       class row_max column_max  id width    area          center  \
# 0     800  Background     800        450   0   450  360000  (225.0, 400.0)
# 1      27       Compo      27        449   1   449   12123   (224.5, 13.5)
# 2      34       Compo      74        439   2    33    1122   (422.5, 57.0)
# 3      21       Compo      68         46   3    34     714    (29.0, 57.5)
# 4      27       Compo      74        253   4    48    1296   (229.0, 60.5)
# 5      33       Compo     120        449   5   449   14817  (224.5, 103.5)
# 6      25       Compo     168        432   6   413   10325  (225.5, 155.5)
# 7      20       Compo     203        106   7    85    1700   (63.5, 193.0)
# 8      49       Compo     262        434   8   422   20678  (223.0, 237.5)
# 9      21       Compo     295        126   9   114    2394   (69.0, 284.5)
# 10     21       Compo     294        433  10   114    2394  (376.0, 283.5)
# 11     27       Compo     334         39  11    27     729   (25.5, 320.5)
# 12     21       Compo     334        199  12   153    3213  (122.5, 323.5)
# 13     22       Compo     387        146  13   134    2948   (79.0, 376.0)
# 14     22       Compo     387        239  14    87    1914  (195.5, 376.0)
# 15     47       Compo     453        434  15   422   19834  (223.0, 429.5)
# 16     21       Compo     487        433  16    94    1974  (386.0, 476.5)
# 17     27       Compo     787        112  17    26     702   (99.0, 773.5)
# 18     27       Compo     787        361  18    22     594  (350.0, 773.5)
# 19     27       Compo     787        239  19    27     729  (225.5, 773.5)
#
#     center_column  center_row
# 0           225.0       400.0
# 1           224.5        13.5
# 2           422.5        57.0
# 3            29.0        57.5
# 4           229.0        60.5
# 5           224.5       103.5
# 6           225.5       155.5
# 7            63.5       193.0
# 8           223.0       237.5
# 9            69.0       284.5
# 10          376.0       283.5
# 11           25.5       320.5
# 12          122.5       323.5
# 13           79.0       376.0
# 14          195.5       376.0
# 15          223.0       429.5
# 16          386.0       476.5
# 17           99.0       773.5
# 18          350.0       773.5
# 19          225.5       773.5

# %%
# ***Step 1*** repetitive list recognition
compos.repetitive_group_recognition()    # group_nontext, group_text
check_valid_group_by_interleaving(compos.compos_dataframe)
compos.pair_groups()                     # group_pair, pair_to, group
compos.list_item_partition()             # list_item
compos.visualize_block('group')
compos.visualize_block('group_pair')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-efa893050242> in <module>()
#       1 # ***Step 1*** repetitive list recognition
# ----> 2 compos.repetitive_group_recognition()    # group_nontext, group_text
#       3 check_valid_group_by_interleaving(compos.compos_dataframe)
#       4 compos.pair_groups()                     # group_pair, pair_to, group
#       5 compos.list_item_partition()             # list_item
#
# D:\git_file\github\doing\UI2CODE\Code-Generation\v10\obj\Compos_DF.py in repetitive_group_recognition(self, show, clean_attrs)
#      75     def repetitive_group_recognition(self, show=False, clean_attrs=True):
#      76         df_nontext = rep.recog_repetition_nontext(self, show)
# ---> 77         df_text = rep.recog_repetition_text(self, show)
#      78         df = self.compos_dataframe
#      79
#
# D:\git_file\github\doing\UI2CODE\Code-Generation\v10\lib\repetition_recognition.py in recog_repetition_text(compos, show, inplace)
#      21     compos_cp.select_by_class(['Text'], replace=True)
#      22
# ---> 23     compos_cp.cluster_dbscan_by_attr('row_min', 5, show=show, show_method='line')
#      24     compos_cp.cluster_dbscan_by_attr('column_min', 5, show=show, show_method='line')
#      25
#
# D:\git_file\github\doing\UI2CODE\Code-Generation\v10\obj\Compos_DF.py in cluster_dbscan_by_attr(self, attr, eps, min_samples, show, show_method)
#     104     def cluster_dbscan_by_attr(self, attr, eps, min_samples=1, show=True, show_method='line'):
#     105         x = np.reshape(list(self.compos_dataframe[attr]), (-1, 1))
# --> 106         clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(x)
#     107         tag = 'cluster_' + attr
#     108         self.compos_dataframe[tag] = clustering.labels_
#
# D:\Anaconda\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     308
#     309         """
# --> 310         X = check_array(X, accept_sparse='csr')
#     311
#     312         if not self.eps > 0.0:
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     584                              " minimum of %d is required%s."
#     585                              % (n_samples, array.shape, ensure_min_samples,
# --> 586                                 context))
#     587
#     588     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
# ***Step 2*** mark compos in same group as a single list, mark compos in same group_pair as a multiple list
lists, non_listed_compos = gather_lists_by_pair_and_group(compos.compos_dataframe[1:])
generate_lists_html_css(lists)
visualize_lists(img_re, lists)

# %%
# ***Step 3*** slice compos as blocks
compos_html = [li.list_obj for li in lists] + non_listed_compos
blocks, non_blocked_compos = slice_blocks(compos_html, 'v')
# visualize_CompoHTMLs(compos_html, img_re)
# visualize_blocks(blocks, img, img_shape)
# blocks[2].visualize_sub_blocks_and_compos(img_re, recursive=True)

# %%
visualize_CompoHTMLs(compos_html, img_re)

# %%
# ***Step 4*** assembly html and css as web page, and react program
html, css = export_html_and_css(blocks)
blk, index = export_react_program(blocks)
